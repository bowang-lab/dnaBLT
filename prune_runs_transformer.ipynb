# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv("Compute_allocations_transformer.csv")
# byte_level = df[df['Patch size'] == 1]
byte_level = df[(df['FLOPs'] == 's') & (df['Patch size'] == 2)]
# byte_level['Global transformer parameters'].sort_values(ascending=False)
fig = px.histogram(byte_level['Global model parameters'])

fig.show()

# %%
byte_level[(byte_level['Global model parameters'] <= 3.2e7) & (byte_level['Global model parameters'] >= 2.8e7)]
# Out:
#      FLOPs  Patch size        Tokens  Encoder parameters  \
# 12       s           2  2.576442e+10          1229824.00
# 63       s           2  2.423669e+10          1229824.00
# 67       s           2  2.239401e+10          1770946.56
# 123      s           2  2.377637e+10          1229824.00
# 248      s           2  2.016762e+10          1770946.56
# 303      s           2  2.297110e+10          1229824.00
# 360      s           2  1.966084e+10          1770946.56
# 412      s           2  2.437497e+10           787087.36
# 501      s           2  2.045149e+10          1229824.00
# 547      s           2  2.352936e+10           787087.36
# 597      s           2  1.993053e+10          1229824.00
# 673      s           2  2.207374e+10           787087.36
# 713      s           2  1.914725e+10          1229824.00
# 816      s           2  2.258760e+10           787087.36
# 855      s           2  2.074405e+10           787087.36
# 928      s           2  2.124284e+10           787087.36
# 962      s           2  1.989688e+10           787087.36
# 1054     s           2  2.041157e+10           787087.36
# 1085     s           2  1.941749e+10           787087.36
# 1111     s           2  1.851574e+10           787087.36
# 1535     s           2  2.111096e+10           442736.64
# 1555     s           2  2.004936e+10           442736.64
# 1584     s           2  1.908941e+10           442736.64
# 1678     s           2  1.958161e+10           442736.64
# 1703     s           2  1.887719e+10           442736.64
# 1725     s           2  1.871995e+10           442736.64
# 1824     s           2  1.919304e+10           442736.64
# 1840     s           2  1.851582e+10           442736.64
#
#       Global model parameters  Decoder parameters  Global model dimension  \
# 12                28335144.96          2459648.00                     768
# 63                29761740.80          2459648.00                     704
# 67                29761740.80          3541893.12                     704
# 123               29515776.00          2459648.00                     640
# 248               31877038.08          3541893.12                     576
# 303               28335144.96          2459648.00                     512
# 360               31483494.40          3541893.12                     512
# 412               29515776.00          2361262.08                     640
# 501               31877038.08          3689472.00                     576
# 547               28335144.96          2361262.08                     512
# 597               31483494.40          3689472.00                     512
# 673               28925460.48          2361262.08                     448
# 713               31335915.52          3689472.00                     448
# 816               28335144.96          3148349.44                     512
# 855               31483494.40          3148349.44                     512
# 928               28925460.48          3148349.44                     448
# 962               31335915.52          3148349.44                     448
# 1054              28335144.96          3148349.44                     384
# 1085              30106091.52          3148349.44                     384
# 1111              31877038.08          3148349.44                     384
# 1535              28335144.96          2656419.84                     384
# 1555              30106091.52          2656419.84                     384
# 1584              31877038.08          2656419.84                     384
# 1678              28285952.00          2656419.84                     320
# 1703              29515776.00          2656419.84                     320
# 1725              31877038.08          3099156.48                     384
# 1824              28285952.00          3099156.48                     320
# 1840              29515776.00          3099156.48                     320
#
#       Encoder/Decoder dimension  Global model layers  Decoder layers
# 12                          320                    4               2
# 63                          320                    5               2
# 67                          384                    5               2
# 123                         320                    6               2
# 248                         384                    8               2
# 303                         320                    9               2
# 360                         384                   10               2
# 412                         256                    6               3
# 501                         320                    8               3
# 547                         256                    9               3
# 597                         320                   10               3
# 673                         256                   12               3
# 713                         320                   13               3
# 816                         256                    9               4
# 855                         256                   10               4
# 928                         256                   12               4
# 962                         256                   13               4
# 1054                        256                   16               4
# 1085                        256                   17               4
# 1111                        256                   18               4
# 1535                        192                   16               6
# 1555                        192                   17               6
# 1584                        192                   18               6
# 1678                        192                   23               6
# 1703                        192                   24               6
# 1725                        192                   18               7
# 1824                        192                   23               7
# 1840                        192                   24               7

# %% [markdown]
# 4e18 FLOPs
# ===
#
# tokens, global model params, decoder params, global model dimension, encoder/decoder dimension, global model layers, decoder layers
#
# Patch size = 2
#
# 4.094315e+10, 11247452,	1224212, 448, 256, 6, 2
#
# 1.993053e+10 31483494, 3689472, 512, 320, 10, 3 (30M run)
#
# 9.492046e+09, 60177695, 5508956, 704, 384, 13, 4
#
# Patch size = 4
#
# 4.937337e+10, 21691515, 1836319, 576, 256, 7, 3
#
# 1.847138e+10, 60177695, 5508956, 704, 384, 13, 4
#
# 9.375604e+09, 120M, 12242125, 896, 512, 16, 5
