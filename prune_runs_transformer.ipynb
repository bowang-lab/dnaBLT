# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv("Compute_allocations_transformer.csv")
# byte_level = df[df['Patch size'] == 1]
byte_level = df[(df['FLOPs'] == 's') & (df['Patch size'] == 2)]
# byte_level['Global transformer parameters'].sort_values(ascending=False)
fig = px.histogram(byte_level['Global model parameters'])

fig.show()

# %%
byte_level[(byte_level['Global model parameters'] <= 1.9e7) & (byte_level['Global model parameters'] >= 1.5e7)]
# Out:
#      FLOPs  Patch size        Tokens  Encoder parameters  \
# 2        s           2  4.106605e+10           787087.36
# 56       s           2  4.001591e+10           787087.36
# 116      s           2  3.457268e+10           787087.36
# 175      s           2  3.622067e+10           787087.36
# 296      s           2  3.585409e+10           787087.36
# 353      s           2  3.289585e+10           787087.36
# 541      s           2  3.743909e+10           442736.64
# 706      s           2  3.458991e+10           442736.64
# 810      s           2  3.604389e+10           442736.64
# 852      s           2  3.305556e+10           442736.64
# 959      s           2  3.339560e+10           442736.64
# 984      s           2  3.139746e+10           442736.64
# 1014     s           2  2.962493e+10           442736.64
# 1170     s           2  3.057223e+10           442736.64
# 1489     s           2  2.547700e+10           442736.64
# 1761     s           2  3.176637e+10           196771.84
# 1784     s           2  3.043513e+10           196771.84
# 1856     s           2  2.998564e+10           196771.84
# 1871     s           2  2.879667e+10           196771.84
# 1890     s           2  2.769839e+10           196771.84
# 1910     s           2  2.668081e+10           196771.84
# 1929     s           2  2.633474e+10           196771.84
#
#       Global model parameters  Decoder parameters  Global model dimension  \
# 2                 15938519.04          1574174.72                     576
# 56                15741747.20          1574174.72                     512
# 116               18890096.64          1574174.72                     512
# 175               16873185.28          1574174.72                     448
# 296               15938519.04          1574174.72                     384
# 353               17709465.60          1574174.72                     384
# 541               15938519.04          1328209.92                     384
# 706               15987712.00          1328209.92                     320
# 810               15938519.04          1770946.56                     384
# 852               17709465.60          1770946.56                     384
# 959               15987712.00          1770946.56                     320
# 984               17217536.00          1770946.56                     320
# 1014              18447360.00          1770946.56                     320
# 1170              15741747.20          1770946.56                     256
# 1489              18890096.64          2213683.20                     256
# 1761              15741747.20          1377402.88                     256
# 1784              16528834.56          1377402.88                     256
# 1856              16528834.56          1574174.72                     256
# 1871              17315921.92          1574174.72                     256
# 1890              18103009.28          1574174.72                     256
# 1910              18890096.64          1574174.72                     256
# 1929              18890096.64          1770946.56                     256
#
#       Encoder/Decoder dimension  Global model layers  Decoder layers
# 2                           256                    4               2
# 56                          256                    5               2
# 116                         256                    6               2
# 175                         256                    7               2
# 296                         256                    9               2
# 353                         256                   10               2
# 541                         192                    9               3
# 706                         192                   13               3
# 810                         192                    9               4
# 852                         192                   10               4
# 959                         192                   13               4
# 984                         192                   14               4
# 1014                        192                   15               4
# 1170                        192                   20               4
# 1489                        192                   24               5
# 1761                        128                   20               7
# 1784                        128                   21               7
# 1856                        128                   21               8
# 1871                        128                   22               8
# 1890                        128                   23               8
# 1910                        128                   24               8
# 1929                        128                   24               9

# %% [markdown]
# 4e18 FLOPs
# ===
#
# tokens, global model params, decoder params, global model dimension, encoder/decoder dimension, global model layers, decoder layers
#
# Patch size = 2
#
# 5.509120e+10, 10625679,	885473,	384, 192, 6, 2 (10M run)
#
# 1.993053e+10 31483494, 3689472, 512, 320, 10, 3 (30M run)
#
# 3.622067e+10, 16873185, 1574175, 448, 256, 7, 2 (17M)
#
# Patch size = 4
#
# 4.937337e+10, 21691515, 1836319, 576, 256, 7, 3
#
# 1.847138e+10, 60177695, 5508956, 704, 384, 13, 4
#
# 9.375604e+09, 120M, 12242125, 896, 512, 16, 5
