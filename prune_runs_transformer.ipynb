# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv("Compute_allocations_transformer.csv")
# byte_level = df[df['Patch size'] == 1]
byte_level = df[(df['FLOPs'] == 's') & (df['Patch size'] == 2)]
# byte_level['Global transformer parameters'].sort_values(ascending=False)
fig = px.histogram(byte_level['Global model parameters'])

fig.show()

# %%
byte_level[(byte_level['Global model parameters'] <= 6.2e7) & (byte_level['Global model parameters'] >= 5.8e7)]
# Out:
#      FLOPs  Patch size        Tokens  Encoder parameters  \
# 202      s           2  1.297946e+10          2410455.04
# 206      s           2  1.225186e+10          3148349.44
# 372      s           2  1.222831e+10          2410455.04
# 376      s           2  1.158039e+10          3148349.44
# 472      s           2  1.300425e+10          1770946.56
# 609      s           2  1.225031e+10          1770946.56
# 685      s           2  1.201516e+10          1770946.56
# 788      s           2  1.152984e+10          1770946.56
# 863      s           2  1.252964e+10          1229824.00
# 867      s           2  1.170016e+10          1770946.56
# 940      s           2  1.228375e+10          1229824.00
# 1029     s           2  1.177695e+10          1229824.00
# 1033     s           2  1.104121e+10          1770946.56
# 1149     s           2  1.132609e+10          1229824.00
# 1153     s           2  1.064398e+10          1770946.56
# 1205     s           2  1.188846e+10          1229824.00
# 1290     s           2  1.141312e+10          1229824.00
# 1384     s           2  1.098919e+10          1229824.00
# 1749     s           2  1.124440e+10           787087.36
#
#       Global model parameters  Decoder parameters  Global model dimension  \
# 202               58195271.68          4820910.08                     832
# 206               58195271.68          6296698.88                     832
# 372               59523481.60          4820910.08                     704
# 376               59523481.60          6296698.88                     704
# 472               58195271.68          5312839.68                     832
# 609               59523481.60          5312839.68                     704
# 685               59031552.00          5312839.68                     640
# 788               59769446.40          5312839.68                     576
# 863               59523481.60          4919296.00                     704
# 867               59523481.60          7083786.24                     704
# 940               59031552.00          4919296.00                     640
# 1029              59769446.40          4919296.00                     576
# 1033              59769446.40          7083786.24                     576
# 1149              59818639.36          4919296.00                     512
# 1153              59818639.36          7083786.24                     512
# 1205              59031552.00          6149120.00                     640
# 1290              59769446.40          6149120.00                     576
# 1384              59818639.36          6149120.00                     512
# 1749              59818639.36          5509611.52                     512
#
#       Encoder/Decoder dimension  Global model layers  Decoder layers
# 202                         448                    7               2
# 206                         512                    7               2
# 372                         448                   10               2
# 376                         512                   10               2
# 472                         384                    7               3
# 609                         384                   10               3
# 685                         384                   12               3
# 788                         384                   15               3
# 863                         320                   10               4
# 867                         384                   10               4
# 940                         320                   12               4
# 1029                        320                   15               4
# 1033                        384                   15               4
# 1149                        320                   19               4
# 1153                        384                   19               4
# 1205                        320                   12               5
# 1290                        320                   15               5
# 1384                        320                   19               5
# 1749                        256                   19               7

# %% [markdown]
# 4e18 FLOPs
# ===
#
# tokens, global model params, decoder params, global model dimension, encoder/decoder dimension, global model layers, decoder layers
#
# Patch size = 2
#
# 4.094315e+10, 11247452,	1224212, 448, 256, 6, 2
#
# 1.993053e+10 31483494, 3689472, 512, 320, 10, 3 (30M run)
#
# 1.188846e+10, 59031552, 6149120, 640, 320, 12, 5 (60M run)
#
# Patch size = 4
#
# 4.937337e+10, 21691515, 1836319, 576, 256, 7, 3
#
# 1.847138e+10, 60177695, 5508956, 704, 384, 13, 4
#
# 9.375604e+09, 120M, 12242125, 896, 512, 16, 5
